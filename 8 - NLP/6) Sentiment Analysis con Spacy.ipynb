# %%
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob

# %%
nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')
text = 'I had a really horrible day. It was the worst day ever! But every now and then I have a really good day that makes me happy.'
doc = nlp(text)

# %%
doc._.polarity
# Out:
# -0.125

# %%
doc._.subjectivity
# Out:
# 0.9

# %%
text = "I'm very happy. I'm working on a beautiful project."
doc = nlp(text)

# %%
doc._.polarity
# Out:
# 0.925

# %%
doc._.subjectivity
# Out:
# 1.0

# %%
text = "This book is very simple and enjoyable to study."
doc = nlp(text)

# %%
doc._.polarity
# Out:
# 0.25

# %%
doc._.subjectivity
# Out:
# 0.5321428571428571

# %% [markdown]
# # CONFRONTIAMO IL NOSTRO MODELLO NAIVE BAYES CON SPACY
#
# ### - Caricare il dataset SMALL_IMDB.csv
# ### - Splittare il dataset in train e test
# ### - Pulire i dataset di train e test (salvare il dataset di test non pulitò, servirà con spacy)
# ### - Fare il training del modello Naive Bayes
# ### - Testare il modello sul dataset di test
# ### - Utilizzare la funzione polarity di spacy per calcolare la sentiment (scrivere opportuna funzione che associa al valore numerico le label positive e negative)
# ### - Scrivere una funzione per calcolare l'accuracy ottenuta dai risultati spacy

# %% [markdown]
# ## Puliamo il dataset, addestriamo il modello e valutiamo l'accuracy

# %%
import pandas as pd

# %%
dataset = pd.read_csv('datasets/Lezione_5-sentiment_Analysis/SMALL_IMDB.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
data_train, data_test, y_train, y_test = train_test_split(dataset['review'], dataset['sentiment'], test_size=0.20, random_state=40)

# %%
import string
import spacy
from nltk.corpus import stopwords
import re

english_stopwords = stopwords.words('english')
nlp = spacy.load('en_core_web_sm')
punctuation = set(string.punctuation)

def data_cleaner(sentence):
    sentence = sentence.lower()
    for c in string.punctuation:
        sentence = sentence.replace(c, " ")
    document = nlp(sentence)
    sentence = ' '.join(token.lemma_ for token in document)
    sentence = ' '.join(word for word in sentence.split() if word not in english_stopwords)
    sentence = re.sub('\d', '', sentence)
    
    return sentence

# %%
data_train_cleaned = []
for i,r in enumerate(data_train):
    data_train_cleaned.append(data_cleaner(r))

# %%
data_test_cleaned = []
for r in data_test:
    data_test_cleaned.append(data_cleaner(r))

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer()
data_train_cleaned_vectorized = vec.fit_transform(data_train_cleaned).toarray()
data_test_cleaned_vectorized = vec.transform(data_test_cleaned).toarray()

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(data_train_cleaned_vectorized, y_train)
# Out:
# MultinomialNB()

# %%
model.score(data_test_cleaned_vectorized, y_test)
# Out:
# 0.833

# %% [markdown]
# ## Valutiamo Spacy

# %%
def sentiment_checker(value, label, text):
    if (value > 0 and label == 'positive') or (value < 0 and label == 'negative'):
        return 1
    else:
        #print(text)
        print("POLARITY SPACY: "+str(value))
        print("REAL LABEL: "+label)
        print("OUR SA MODEL: "+model.predict(vec.transform([data_cleaner(text)]))[0])
        print("----------------------------------------------------------------")
        return 0

# %%
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob
nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')

count = 0
for r,s in zip(data_test,y_test):
    doc = nlp(r)
    count+=sentiment_checker(doc._.polarity,s,r)
# Out:
# POLARITY SPACY: 0.06350649350649351
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.06478696741854637
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.014194139194139189
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.17006653069153066
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.2435897435897436
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.18091313448456306
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.08333333333333336
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.24454365079365079
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.29194444444444445
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.00479989868287741
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.06774812489098203
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.03888888888888888
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.1394097222222222
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.023639455782312923
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.016666666666666663
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.006249999999999994
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.16363636363636364
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.15550793650793654
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.05267857142857143
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.13828042328042328
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.22770833333333335
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.18541666666666667
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.16458333333333333
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: -0.05795454545454546
# REAL LABEL: positive
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: -0.04
# REAL LABEL: positive
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.010863095238095238
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: -0.020579710144927547
# REAL LABEL: positive
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.12700892857142856
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.11723169191919192
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.25
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.3018939393939394
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.10613445378151261
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.2158950617283951
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.029040404040404044
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.07530776515151517
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.10619834710743802
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.004609307359307357
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.02890604890604892
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.06731060606060606
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.14053030303030303
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.11400112233445565
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.15
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.086557165733995
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.018877551020408157
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.02072649572649572
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.012396480331262935
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.08431372549019608
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.05233516483516482
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.11747685185185183
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.11615151515151516
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.006106321839080462
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.1547348484848485
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.009999999999999998
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.04154761904761905
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.025024801587301616
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.007859531772575246
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.16865151515151516
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.26647727272727273
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.12857142857142856
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.03833333333333333
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.04351851851851852
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.1308943833943834
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.2350696405044231
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.1541921041921042
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.11242424242424244
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.10011520737327194
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.06407312925170072
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.24578924162257496
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: -0.05833333333333332
# REAL LABEL: positive
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.06021645021645023
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: -0.014772727272727281
# REAL LABEL: positive
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.014935064935064978
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.07500000000000001
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.1605848861283644
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.06999999999999999
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.02320861678004536
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.03692956349206349
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: -0.04135802469135801
# REAL LABEL: positive
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.011031746031746052
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.07900950999355255
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.08460144927536231
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.03106414310515873
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.04347826086956523
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: -0.010542883494543671
# REAL LABEL: positive
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.0010328696804106686
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.29
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.09236111111111107
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.19083333333333335
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.21615013774104683
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.0669642857142857
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.1159848484848485
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.1717857142857143
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.024206349206349204
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.06620370370370371
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.16346153846153846
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0.007608695652173919
# REAL LABEL: negative
# OUR SA MODEL: positive
# ----------------------------------------------------------------
# POLARITY SPACY: 0.1875
# REAL LABEL: negative
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: -0.04453463203463204
# REAL LABEL: positive
# OUR SA MODEL: negative
# ----------------------------------------------------------------
# POLARITY SPACY: 0